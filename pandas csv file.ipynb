# %%
import pandas as pd

# %%
d=pd.read_csv("C:\\Users\\SSS\\Downloads\\titanic (1).csv")

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d1=pd.read_csv("C:\\Users\\SSS\\Desktop\\A.csv")

# %%
d1
# Out:
#    p1  23  m
# 0  p2  24  f
# 1  p3  25  m
# 2  p4  26  f
# 3  p5  27  f
# 4  p6  28  m
# 5  p7  25  f

# %%
d1=pd.read_csv("C:\\Users\\SSS\\Desktop\\A.csv",header=None)

# %%
d1
# Out:
#     0   1  2
# 0  p1  23  m
# 1  p2  24  f
# 2  p3  25  m
# 3  p4  26  f
# 4  p5  27  f
# 5  p6  28  m
# 6  p7  25  f

# %%
d2=pd.read_csv("C:\\Users\\SSS\\Desktop\\A2.csv")

# %%
d2
# Out:
#    asdd  xcdfvf dvfdv
# 0  Name  Gender   Age
# 1    p1       m     1
# 2    p2       f     2
# 3    p3       f     3
# 4    p4       m     4
# 5    p5       f     5
# 6    p6       m     3

# %%
import pandas as pd
d2=pd.read_csv("C:\\Users\\SSS\\Desktop\\A2.csv",header=1)

# %%
d2
# Out:
#   Name Gender  Age
# 0   p1      m    1
# 1   p2      f    2
# 2   p3      f    3
# 3   p4      m    4
# 4   p5      f    5
# 5   p6      m    3

# %%
# usecols= to convert particular column of csv to dataframe
data=pd.read_csv("C:\\Users\\SSS\\Downloads\\titanic (1).csv",usecols=["PassengerId","Survived","Pclass"])

# %%
data
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
d3=pd.read_csv("C:\\Users\\SSS\\Desktop\\A3.csv",header=None)

# %%
d3
# Out:
#     0  1  2
# 0  p1  2  m
# 1  p2  3  f
# 2  p3  4  f
# 3  p4  5  m
# 4  p5  6  m
# 5  p6  7  f
# 6  p7  7  f

# %%
d3=pd.read_csv("C:\\Users\\SSS\\Desktop\\A3.csv",names=["a","b","c"]) # use name if we dont have header

# %%
d3
# Out:
#     a  b  c
# 0  p1  2  m
# 1  p2  3  f
# 2  p3  4  f
# 3  p4  5  m
# 4  p5  6  m
# 5  p6  7  f
# 6  p7  7  f

# %%
pd.read_csv("C:\\Users\\SSS\\Desktop\\A3.csv",nrows=5)
# Out:
#    p1  2  m
# 0  p2  3  f
# 1  p3  4  f
# 2  p4  5  m
# 3  p5  6  m
# 4  p6  7  f

# %%
pd.read_csv("C:\\Users\\SSS\\Desktop\\A3.csv",nrows=5,header=None)
# Out:
#     0  1  2
# 0  p1  2  m
# 1  p2  3  f
# 2  p3  4  f
# 3  p4  5  m
# 4  p5  6  m

# %%
pd.read_csv("C:\\Users\\SSS\\Desktop\\A3.csv",nrows=3,header=None)
# Out:
#     0  1  2
# 0  p1  2  m
# 1  p2  3  f
# 2  p3  4  f

# %%
pd.read_csv("C:\\Users\\SSS\\Desktop\\A3.csv",skiprows=[1,3],header=None)  # here skiprows removed 1st index and 3rd index
# Out:
#     0  1  2
# 0  p1  2  m
# 1  p3  4  f
# 2  p5  6  m
# 3  p6  7  f
# 4  p7  7  f

# %%
# try to analyse column vise because unnecessery data is there,unnecessery value convert to NaN by na_values=[list of values]

# %%
pd.read_csv("C:\\Users\\SSS\\Desktop\\A4.csv",header=None,na_values=[-234,577]) 
#dont use list becoz if we have same values in  1 & 2 index,it change both to Nan ,use dict
# Out:
#     0    1    2
# 0  p1  3.0    m
# 1  p2  4.0    f
# 2  p3  5.0    f
# 3  p4  NaN  NaN
# 4  p5  NaN    f

# %%
pd.read_csv("C:\\Users\\SSS\\Desktop\\A4.csv",header=None,na_values={1:[-234,577],2:[-234]})
# Out:
#     0    1    2
# 0  p1  3.0    m
# 1  p2  4.0    f
# 2  p3  5.0    f
# 3  p4  NaN  NaN
# 4  p5  NaN    f

# %%
pd.read_csv("C:\\Users\\SSS\\Desktop\\A4.csv",header=None,na_values={1:[-234,577]})
# Out:
#     0    1     2
# 0  p1  3.0     m
# 1  p2  4.0     f
# 2  p3  5.0     f
# 3  p4  NaN  -234
# 4  p5  NaN     f

# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\SSS\\Downloads\\titanic (1).csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[["PassengerId","Pclass"]]

# %%
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
# once after we perform the different tool and operation on the DataFrame,
# we needed to convert the DF into CSV back to convert we use 'varianblr.to_csv(pth\filename.csv)'
df1.to_csv("C:\\Users\\SSS\\Downloads\\titanic (1).csv")
df1
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
# hear the index is making a new colums so to avoid this use index=False
df1.to_csv("C:\\Users\\SSS\\Downloads\\titanic.csv")
df1
# Out:
#      PassengerId  Pclass
# 0              1       3
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [891 rows x 2 columns]

# %%
# as we convert the csv file into DataFrame can can also convert the text file into the DataFrame 
# in real time the tex is not separated by only ',' , it may be saperated by '-' or ' ' and .....etc.
# So to come out of this situation we use delimiter to break the values in the given text file.

# %%
# attribute

# %%
d1=pd.Series([1,2,3,4,5])

# %%
d1.axes
# Out:
# [RangeIndex(start=0, stop=5, step=1)]

# %%
d.axes
# Out:
# [RangeIndex(start=0, stop=891, step=1),
#  Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object')]

# %%
d.columns  # column index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
d.index  #row index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#method

# %%
d.head()    # give top 5 rows-default is 5
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
d.head(10)    # give 10 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
d.head(-3)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d.tail()   #give end 5 rows
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
d.tail(10) #give end 10 rows
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d.tail(-3)
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# 7                  Palsson, Master. Gosta Leonard    male   2.0      3      1
# ...

# %%
d1.shape
# Out:
# (5,)

# %%
d.shape
# Out:
# (891, 12)

# %%
d.T   # can apply only on dataframe not on series becoz shape is immutable in series
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %%
d.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
d1.values
# Out:
# array([1, 2, 3, 4, 5], dtype=int64)

# %%
d1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
d.empty
# Out:
# False

# %%
d1.empty
# Out:
# False

# %%
a=pd.Series()
# Out:
# C:\Users\SSS\AppData\Local\Temp\ipykernel_11368\1633287561.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   a=pd.Series()

# %%
a.empty
# Out:
# True

# %%
b=pd.DataFrame()

# %%
a.empty
# Out:
# True

# %%
import pandas as pd
import numpy as np
df6 = pd.DataFrame({'A' : [np.nan]})
df6
# Out:
#     A
# 0 NaN

# %%
df6.empty
# Out:
# False

# %%
df6.dropna().empty
# Out:
# True

# %%
d.ndim
# Out:
# 2

# %%
d1.ndim
# Out:
# 1

# %%
d.size  #give no.of non null values(891 rows*12 columns)
# Out:
# 10692

# %%
d1.size
# Out:
# 5

# %%
d.shape
# Out:
# (891, 12)

# %%
d.info()  # info of dataset ,consider each row as datapoint,non-null denotes dataset dont have NaN values
# in Age column we have only 714 values remaining are NaN values ,same as in Cabin
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# object-if u have different datatype in array,u want to preserve this use object ,dont convert int to object,
# only convert catogarical column to object

# %%
import numpy as np

# %%
np.array([1,1.1,"a"])  # get each element in string
# Out:
# array(['1', '1.1', 'a'], dtype='<U32')

# %%
np.array([1,1.1,"a"],dtype=object)
# Out:
# array([1, 1.1, 'a'], dtype=object)

# %%
d.describe()  ## Describe()  ----> 
'''describe()- The describe() method is used for calculating some statistical data like
percentile, mean and std of the numerical values of the Series or DataFrame'''
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data5 = [[10, 18, 11], [13, 15, 8], [9, 20, 3]]
data5
# Out:
# [[10, 18, 11], [13, 15, 8], [9, 20, 3]]

# %%
df11= pd.DataFrame(data5)
df11
# Out:
#     0   1   2
# 0  10  18  11
# 1  13  15   8
# 2   9  20   3

# %%
df11.describe()
# Out:
#                0          1          2
# count   3.000000   3.000000   3.000000
# mean   10.666667  17.666667   7.333333
# std     2.081666   2.516611   4.041452
# min     9.000000  15.000000   3.000000
# 25%     9.500000  16.500000   5.500000
# 50%    10.000000  18.000000   8.000000
# 75%    11.500000  19.000000   9.500000
# max    13.000000  20.000000  11.000000
