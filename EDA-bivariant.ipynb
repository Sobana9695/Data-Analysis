# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# pie plot-if u have numerical column,mainly used for ratio purpose

# %%
plt.pie([60,20,10,90],labels=["maths","physics","chemistry","biology"],autopct="%0.2f%%",explode=[0.2,0,0,0],radius=3)
plt.show()

# %%
data=pd.read_csv("C:\\Users\\SSS\\Downloads\\iris.csv",names=["sl","sw","pl","pw","species"])

# %%
data
# Out:
#       sl   sw   pl   pw         species
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(data=data,x="sl",y="sw",hue="species")
plt.show()

# %%
sns.scatterplot(data=data,x="pl",y="pw",hue="species")
plt.show()

# %%
m=sns.FacetGrid(data=data,hue="species",size=5)
m.map(plt.scatter,"pl","pw")
m.add_legend()

# %%
sns.pairplot(data,hue="species",size=3)  # it is bivariant analysis,take all numerical values and pair it

# %%
# from above pl,pw are good two pair to build module

# %%
sns.boxplot(data=data,y="pl",x="species",hue="species")
# Out:
# <AxesSubplot:xlabel='species', ylabel='pl'>

# %%
# boxplot,swarm plot,box plot also called bivarient-becoz,x axis catagorical

# %%
# regression plot
sns.regplot(data=data,x="sl",y="sw")   # linear line
# Out:
# <AxesSubplot:xlabel='sl', ylabel='sw'>

# %%
# rel-relational plot
sns.relplot(data=data,x="pw",y="pl",col="species")

# %%
d=pd.read_csv("C:\\Users\\SSS\\Downloads\\chocolate_bars.csv")

# %%
d
# Out:
#         id manufacturer company_location  year_reviewed         bean_origin  \
# 0     2454         5150           U.S.A.           2019            Tanzania
# 1     2458         5150           U.S.A.           2019  Dominican Republic
# 2     2454         5150           U.S.A.           2019          Madagascar
# 3     2542         5150           U.S.A.           2021                Fiji
# 4     2546         5150           U.S.A.           2021           Venezuela
# ...    ...          ...              ...            ...                 ...
# 2525  1205       Zotter          Austria           2014               Blend
# 2526  1996       Zotter          Austria           2017            Colombia
# 2527  2036       Zotter          Austria           2018               Blend
# 2528  2170       Zotter          Austria           2018               Congo
# 2529  2170       Zotter          Austria           2018              Belize
#
# ...

# %%
d.head()
# Out:
#      id manufacturer company_location  year_reviewed         bean_origin  \
# 0  2454         5150           U.S.A.           2019            Tanzania
# 1  2458         5150           U.S.A.           2019  Dominican Republic
# 2  2454         5150           U.S.A.           2019          Madagascar
# 3  2542         5150           U.S.A.           2021                Fiji
# 4  2546         5150           U.S.A.           2021           Venezuela
#
#                  bar_name  cocoa_percent  num_ingredients ingredients  \
# 0   Kokoa Kamili, batch 1           76.0              3.0       B,S,C
# 1         Zorzal, batch 1           76.0              3.0       B,S,C
# 2  Bejofo Estate, batch 1           76.0              3.0       B,S,C
# 3   Matasawalevu, batch 1           68.0              3.0       B,S,C
# 4   Sur del Lago, batch 1           72.0              3.0       B,S,C
#
#                               review  rating
# 0          rich cocoa, fatty, bready    3.25
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530 entries, 0 to 2529
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2530 non-null   int64
#  1   manufacturer      2530 non-null   object
#  2   company_location  2530 non-null   object
#  3   year_reviewed     2530 non-null   int64
#  4   bean_origin       2530 non-null   object
#  5   bar_name          2530 non-null   object
#  6   cocoa_percent     2530 non-null   float64
#  7   num_ingredients   2443 non-null   float64
#  8   ingredients       2443 non-null   object
#  9   review            2530 non-null   object
#  10  rating            2530 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 217.5+ KB

# %%
d.describe()
# Out:
#                 id  year_reviewed  cocoa_percent  num_ingredients       rating
# count  2530.000000    2530.000000    2530.000000      2443.000000  2530.000000
# mean   1429.800791    2014.374308      71.639723         3.041343     3.196344
# std     757.648556       3.968267       5.616724         0.913728     0.445321
# min       5.000000    2006.000000      42.000000         1.000000     1.000000
# 25%     802.000000    2012.000000      70.000000         2.000000     3.000000
# 50%    1454.000000    2015.000000      70.000000         3.000000     3.250000
# 75%    2079.000000    2018.000000      74.000000         4.000000     3.500000
# max    2712.000000    2021.000000     100.000000         6.000000     4.000000

# %%
d1=pd.read_csv("C:\\Users\\SSS\\Downloads\\flavors_of_cacao.csv",header=0,names=["COM","SO","REF","R.DATE","C.PER","COM.LOC","RATING","BEAN-TYPE","BEAN-ORI"])

# %%
d1
# Out:
#      Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                      A. Morin                       Agua Grande  1876
# 1                      A. Morin                             Kpime  1676
# 2                      A. Morin                            Atsane  1676
# 3                      A. Morin                             Akata  1680
# 4                      A. Morin                            Quilla  1704
# ...                         ...                               ...   ...
# 1790                     Zotter                              Peru   647
# 1791                     Zotter                             Congo   749
# 1792                     Zotter                      Kerala State   749
# 1793                     Zotter                      Kerala State   781
# 1794                     Zotter                Brazil, Mitzi Blue   486
#
#       Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# ...

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Company
# (Maker-if known)         1795 non-null   object
#  1   Specific Bean Origin
# or Bar Name  1795 non-null   object
#  2   REF                               1795 non-null   int64
#  3   Review
# Date                       1795 non-null   int64
#  4   Cocoa
# Percent                     1795 non-null   object
#  5   Company
# Location                  1795 non-null   object
#  6   Rating                            1795 non-null   float64
#  7   Bean
# Type                         1794 non-null   object
#  8   Broad Bean
# Origin                 1794 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 126.3+ KB

# %%
d1.shape
# Out:
# (1795, 9)

# %%
d1=d1.rename(columns={"specify origin":"so","REVIEWDATE":"rd"})

# %%
d1
# Out:
#      Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                      A. Morin                       Agua Grande  1876
# 1                      A. Morin                             Kpime  1676
# 2                      A. Morin                            Atsane  1676
# 3                      A. Morin                             Akata  1680
# 4                      A. Morin                            Quilla  1704
# ...                         ...                               ...   ...
# 1790                     Zotter                              Peru   647
# 1791                     Zotter                             Congo   749
# 1792                     Zotter                      Kerala State   749
# 1793                     Zotter                      Kerala State   781
# 1794                     Zotter                Brazil, Mitzi Blue   486
#
#       Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# ...

# %%
df=pd.read_csv("C:\\Users\\SSS\\Downloads\\flavors_of_cacao.csv",header=0,names=["COM","SO","REF","R.DATE","C.PER","COM.LOC","RATING","BEAN-TYPE","BEAN-ORI"])

# %%
df
# Out:
#            COM                  SO   REF  R.DATE C.PER  COM.LOC  RATING  \
# 0     A. Morin         Agua Grande  1876    2016   63%   France    3.75
# 1     A. Morin               Kpime  1676    2015   70%   France    2.75
# 2     A. Morin              Atsane  1676    2015   70%   France    3.00
# 3     A. Morin               Akata  1680    2015   70%   France    3.50
# 4     A. Morin              Quilla  1704    2015   70%   France    3.50
# ...        ...                 ...   ...     ...   ...      ...     ...
# 1790    Zotter                Peru   647    2011   70%  Austria    3.75
# 1791    Zotter               Congo   749    2011   65%  Austria    3.00
# 1792    Zotter        Kerala State   749    2011   65%  Austria    3.50
# 1793    Zotter        Kerala State   781    2011   62%  Austria    3.25
# 1794    Zotter  Brazil, Mitzi Blue   486    2010   65%  Austria    3.00
#
#       BEAN-TYPE  BEAN-ORI
# 0                Sao Tome
# 1                    Togo
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   COM        1795 non-null   object
#  1   SO         1795 non-null   object
#  2   REF        1795 non-null   int64
#  3   R.DATE     1795 non-null   int64
#  4   C.PER      1795 non-null   float64
#  5   COM.LOC    1795 non-null   object
#  6   RATING     1795 non-null   float64
#  7   BEAN-TYPE  1794 non-null   object
#  8   BEAN-ORI   1794 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 126.3+ KB

# %%
df.describe()
# Out:
#                REF       R.DATE       RATING
# count  1795.000000  1795.000000  1795.000000
# mean   1035.904735  2012.325348     3.185933
# std     552.886365     2.927210     0.478062
# min       5.000000  2006.000000     1.000000
# 25%     576.000000  2010.000000     2.875000
# 50%    1069.000000  2013.000000     3.250000
# 75%    1502.000000  2015.000000     3.500000
# max    1952.000000  2017.000000     5.000000

# %%
df["COM"].unique().shape
# Out:
# (416,)

# %%
df["BEAN-TYPE"].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1790    False
# 1791    False
# 1792    False
# 1793    False
# 1794    False
# Name: BEAN-TYPE, Length: 1795, dtype: bool

# %%
df["BEAN-TYPE"].isnull().sum()
# Out:
# 1

# %%
df["BEAN-TYPE"]=df["BEAN-TYPE"].fillna(value=0)

# %%
df["BEAN-TYPE"]
# Out:
# 0
# 1
# 2
# 3
# 4
#           ...
# 1790
# 1791    Forastero
# 1792    Forastero
# 1793
# 1794
# Name: BEAN-TYPE, Length: 1795, dtype: object

# %%
df.replace({"BEAN-TYPE":{0:"Forastero"}})
# Out:
#            COM                  SO   REF  R.DATE C.PER  COM.LOC  RATING  \
# 0     A. Morin         Agua Grande  1876    2016   63%   France    3.75
# 1     A. Morin               Kpime  1676    2015   70%   France    2.75
# 2     A. Morin              Atsane  1676    2015   70%   France    3.00
# 3     A. Morin               Akata  1680    2015   70%   France    3.50
# 4     A. Morin              Quilla  1704    2015   70%   France    3.50
# ...        ...                 ...   ...     ...   ...      ...     ...
# 1790    Zotter                Peru   647    2011   70%  Austria    3.75
# 1791    Zotter               Congo   749    2011   65%  Austria    3.00
# 1792    Zotter        Kerala State   749    2011   65%  Austria    3.50
# 1793    Zotter        Kerala State   781    2011   62%  Austria    3.25
# 1794    Zotter  Brazil, Mitzi Blue   486    2010   65%  Austria    3.00
#
#       BEAN-TYPE  BEAN-ORI
# 0                Sao Tome
# 1                    Togo
# ...

# %%
df["BEAN-TYPE"].isnull().sum()
# Out:
# 0

# %%
df["BEAN-ORI"].isnull().sum()
# Out:
# 1

# %%
df["BEAN-ORI"]=df["BEAN-ORI"].fillna(value=0)

# %%
df["BEAN-ORI"]
# Out:
# 0       Sao Tome
# 1           Togo
# 2           Togo
# 3           Togo
# 4           Peru
#           ...
# 1790        Peru
# 1791       Congo
# 1792       India
# 1793       India
# 1794      Brazil
# Name: BEAN-ORI, Length: 1795, dtype: object

# %%
df["BEAN-ORI"].isnull().sum()
# Out:
# 0

# %%
df["BEAN-TYPE"].unique()
# Out:
# array(['\xa0', 'Criollo', 'Trinitario', 'Forastero (Arriba)', 'Forastero',
#        'Forastero (Nacional)', 'Criollo, Trinitario',
#        'Criollo (Porcelana)', 'Blend', 'Trinitario (85% Criollo)',
#        'Forastero (Catongo)', 'Forastero (Parazinho)',
#        'Trinitario, Criollo', 'CCN51', 'Criollo (Ocumare)', 'Nacional',
#        'Criollo (Ocumare 61)', 'Criollo (Ocumare 77)',
#        'Criollo (Ocumare 67)', 'Criollo (Wild)', 'Beniano', 'Amazon mix',
#        'Trinitario, Forastero', 'Forastero (Arriba) ASS', 'Criollo, +',
#        'Amazon', 'Amazon, ICS', 'EET', 'Blend-Forastero,Criollo',
#        'Trinitario (Scavina)', 'Criollo, Forastero', 'Matina',
#        'Forastero(Arriba, CCN)', 'Nacional (Arriba)',
#        'Forastero (Arriba) ASSS', 'Forastero, Trinitario',
#        'Forastero (Amelonado)', nan, 'Trinitario, Nacional',
#        'Trinitario (Amelonado)', 'Trinitario, TCGA', 'Criollo (Amarru)'],
#       dtype=object)

# %%
df["BEAN-TYPE"].value_counts()
# Out:
#                             887
# Trinitario                  419
# Criollo                     153
# Forastero                    87
# Forastero (Nacional)         52
# Blend                        41
# Criollo, Trinitario          39
# Forastero (Arriba)           37
# Criollo (Porcelana)          10
# Trinitario, Criollo           9
# Forastero (Parazinho)         8
# Forastero (Arriba) ASS        6
# Nacional (Arriba)             3
# Matina                        3
# EET                           3
# Beniano                       3
# Criollo (Ocumare 61)          2
# Trinitario, Forastero         2
# Trinitario (85% Criollo)      2
# Forastero (Catongo)           2
# Criollo, Forastero            2
# Amazon, ICS                   2
# Criollo (Amarru)              2
# Amazon mix                    2
# Nacional                      2
# Criollo (Ocumare)             1
# Criollo (Ocumare 67)          1
# Trinitario, TCGA              1
# Trinitario (Amelonado)        1
# ...

# %%
g=df.groupby("R.DATE")

# %%
g

# %%
g.ngroups
# Out:
# 12

# %%
g.groups
# Out:
# {2006: [86, 87, 241, 242, 243, 244, 245, 246, 247, 465, 554, 574, 575, 576, 616, 644, 645, 646, 647, 648, 649, 739, 765, 766, 767, 768, 769, 770, 878, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1176, 1177, 1178, 1237, 1292, 1293, 1294, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1423, 1424, 1425, 1439, 1440, 1441, 1442, 1443, 1698, 1699, 1700, 1701, 1702], 2007: [60, 61, 62, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 142, 143, 240, 287, 288, 326, 419, 420, 421, 464, 523, 524, 525, 526, 527, 528, 533, 534, 566, 567, 568, 569, 570, 571, 572, 573, 764, 780, 975, 1010, 1011, 1112, 1113, 1175, 1276, 1288, 1289, 1290, 1291, 1322, 1369, 1370, 1371, 1435, 1436, 1437, 1438, 1621, 1655, 1656, 1657, 1658, 1659, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1720, 1721, 1722, 1723], 2008: [59, 136, 205, 206, 207, 208, 209, 210, 211, 239, 286, 321, 322, 323, 324, 325, 339, 340, 341, 342, 343, 344, 379, 418, 435, 436, 437, 441, 442, 443, 444, 462, 463, 53
# ...

# %%
g.get_group(2006)["R.DATE"]
# Out:
# 86      2006
# 87      2006
# 241     2006
# 242     2006
# 243     2006
#         ...
# 1698    2006
# 1699    2006
# 1700    2006
# 1701    2006
# 1702    2006
# Name: R.DATE, Length: 72, dtype: int64

# %%
df["C.PER"].value_counts()
# Out:
# 70%      672
# 75%      222
# 72%      189
# 65%       78
# 80%       72
# 74%       50
# 68%       47
# 60%       43
# 73%       40
# 85%       36
# 64%       34
# 77%       33
# 71%       31
# 67%       27
# 76%       23
# 66%       23
# 100%      20
# 82%       17
# 78%       17
# 55%       16
# 62%       14
# 63%       12
# 69%       10
# 90%        8
# 61%        8
# 88%        8
# 58%        8
# 81%        5
# 83%        4
# 84%        4
# 72.5%      4
# 91%        3
# 56%        2
# 73.5%      2
# 99%        2
# 89%        2
# 53%        1
# 46%        1
# 60.5%      1
# 57%        1
# 79%        1
# 86%        1
# 50%        1
# 42%        1
# 87%        1
# Name: C.PER, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
g1=df.groupby("C.PER")

# %%
g1

# %%
g1.ngroups
# Out:
# 45

# %%
g1.get_group("70%").value_counts()
# Out:
# COM                        SO                              REF   R.DATE  C.PER  COM.LOC      RATING  BEAN-TYPE   BEAN-ORI
# A. Morin                   Akata                           1680  2015    70%    France       3.50                Togo                  1
# Ohiyo                      Tanzania                        1598  2015    70%    U.S.A.       3.00                Tanzania              1
# Omnom                      Kakao Kamili, Kilombero Valley  1816  2016    70%    Iceland      3.75    Trinitario  Tanzania              1
#                            Papua New Guinea                1247  2014    70%    Iceland      3.00                Papua New Guinea      1
# Original Beans (Felchlin)  D.R. Congo, Cru Virunga         331   2009    70%    Switzerland  3.00    Forastero   Congo                 1
#                                                                                                                                       ..
# ...

# %%
plt.hist(df["R.DATE"],bins=5,rwidth=0.97)
# Out:
# (array([242., 234., 360., 431., 528.]),
#  array([2006. , 2008.2, 2010.4, 2012.6, 2014.8, 2017. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df["RATING"],bins=5,rwidth=0.97)
# Out:
# (array([ 17., 173., 903., 700.,   2.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df["C.PER"],bins=5,rwidth=0.97,label="R.DATE")
plt.xlabel("C.PER")
plt.legend(loc=2)

# %%
sns.histplot(data=df,x="C.PER",bins=5,color="green",hue="R.DATE")
# Out:
# <AxesSubplot:xlabel='C.PER', ylabel='Count'>

# %%
m=sns.FacetGrid(data=df,hue="R.DATE",size=10)
m.map(sns.histplot,"RATING")
m.add_legend()

# %%
sns.distplot(x=df["RATING"],hist=False)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x=df["R.DATE"],hist=False)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.scatterplot(data=df,x="RATING",y="C.PER",hue="RATING")
# Out:
# <AxesSubplot:xlabel='RATING', ylabel='C.PER'>

# %%
sns.pairplot(df,hue="R.DATE",size=3)

# %%
m=sns.FacetGrid(data=df,hue="R.DATE",size=5)
m.map(plt.scatter,"C.PER","RATING")
m.add_legend()

# %%
df["C.PER"]=df["C.PER"].str.replace("%","").astype(float)/100

# %%
df["C.PER"]
# Out:
# 0       0.63
# 1       0.70
# 2       0.70
# 3       0.70
# 4       0.70
#         ...
# 1790    0.70
# 1791    0.65
# 1792    0.65
# 1793    0.62
# 1794    0.65
# Name: C.PER, Length: 1795, dtype: float64
