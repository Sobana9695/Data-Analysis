# %%
# how to access rows= loc-label based accessing,iloc-integer based accessing

# %%
import pandas as pd
data=pd.DataFrame({"Name":["p1","p2","p3","p4"],"Gender":["m","f","f","m"],"Age":[21,2,3,4]})

# %%
data
# Out:
#   Name Gender  Age
# 0   p1      m   21
# 1   p2      f    2
# 2   p3      f    3
# 3   p4      m    4

# %%
x=pd.DataFrame({"Name":["p1","p2","p3","p4"],"Gender":["m","f","f","m"],"Age":[21,2,3,4]},index=[1,2,3,4])

# %%
x
# Out:
#   Name Gender  Age
# 1   p1      m   21
# 2   p2      f    2
# 3   p3      f    3
# 4   p4      m    4

# %%
x.loc[1:3]
# Out:
#   Name Gender  Age
# 1   p1      m   21
# 2   p2      f    2
# 3   p3      f    3

# %%
x.iloc[1:3]
# Out:
#   Name Gender  Age
# 2   p2      f    2
# 3   p3      f    3

# %%
x.loc[0:3]
# Out:
#   Name Gender  Age
# 1   p1      m   21
# 2   p2      f    2
# 3   p3      f    3

# %%
x=pd.DataFrame({"Name":["p1","p2","p3","p4"],"Gender":["m","f","f","m"],"Age":[21,2,3,4]},index=["a","b","c","d"])

# %%
x
# Out:
#   Name Gender  Age
# a   p1      m   21
# b   p2      f    2
# c   p3      f    3
# d   p4      m    4

# %%
x.loc[0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 x.loc[0:3]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1180, in _LocIndexer._getitem_axis(self, key, axis)
#    1178 if isinstance(key, slice):
#    1179     self._validate_key(key, axis)
# -> 1180     return self._get_slice_axis(key, axis=axis)
#    1181 elif com.is_bool_indexer(key):
#    1182     return self._getbool_axis(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1214, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1211     return obj.copy(deep=False)
# ...

# %%
x.iloc[0:3]
# Out:
#   Name Gender  Age
# a   p1      m   21
# b   p2      f    2
# c   p3      f    3

# %%
x.iloc["a":"c"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 x.iloc["a":"c"]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1497, in _iLocIndexer._getitem_axis(self, key, axis)
#    1491     raise IndexError(
#    1492         "DataFrame indexer is not allowed for .iloc\n"
#    1493         "Consider using .loc for automatic alignment."
#    1494     )
#    1496 if isinstance(key, slice):
# -> 1497     return self._get_slice_axis(key, axis=axis)
#    1499 if is_iterator(key):
#    1500     key = list(key)
#
# ...

# %%
x.loc["a":"c"]
# Out:
#   Name Gender  Age
# a   p1      m   21
# b   p2      f    2
# c   p3      f    3

# %%
data1=pd.DataFrame({"Name":["p1","p2","p3","p4"],"Gender":["m","f","f","m"],"Age":[21,2,3,4]})

# %%
data1
# Out:
#   Name Gender  Age
# 0   p1      m   21
# 1   p2      f    2
# 2   p3      f    3
# 3   p4      m    4

# %%
data1.loc[data1["Gender"]=="m"]
# Out:
#   Name Gender  Age
# 0   p1      m   21
# 3   p4      m    4

# %%
data1.loc[(data1["Gender"]=="m") | (data1["Gender"]=="f")]
# Out:
#   Name Gender  Age
# 0   p1      m   21
# 1   p2      f    2
# 2   p3      f    3
# 3   p4      m    4

# %%
data1.loc[(data1["Gender"]=="m") | (data1["Age"]==21)]
# Out:
#   Name Gender  Age
# 0   p1      m   21
# 3   p4      m    4

# %%
data1.loc[(data1["Gender"]=="m") & (data1["Age"]==21)]
# Out:
#   Name Gender  Age
# 0   p1      m   21

# %%
data2=pd.DataFrame({"Name":["p1","p2","p3","p4"],"Gender":["m","f","f","m"],"Age":[21,2,3,4],"Salary":["25k","30k","35k","40k"]})

# %%
data2
# Out:
#   Name Gender  Age Salary
# 0   p1      m   21    25k
# 1   p2      f    2    30k
# 2   p3      f    3    35k
# 3   p4      m    4    40k

# %%
data2.loc[(data2["Gender"]=="m") & (data2["Salary"]>="25k")]
# Out:
#   Name Gender  Age Salary
# 0   p1      m   21    25k
# 3   p4      m    4    40k

# %%
data2.loc[(data2["Gender"]=="m") | (data2["Gender"]=="f"),["Name"]]
# Out:
#   Name
# 0   p1
# 1   p2
# 2   p3
# 3   p4

# %%
data2.loc[(data2["Gender"]=="m") | (data2["Gender"]=="f"),["Name","Age"]]
# Out:
#   Name  Age
# 0   p1   21
# 1   p2    2
# 2   p3    3
# 3   p4    4

# %%
data2.loc[(data2["Gender"]=="m") | (data2["Gender"]=="f"),["Salary","Age"]]=[0,1]

# %%
data2
# Out:
#   Name Gender  Age Salary
# 0   p1      m    1      0
# 1   p2      f    1      0
# 2   p3      f    1      0
# 3   p4      m    1      0

# %%
data2.loc[(data2["Gender"]=="m"),["Salary","Age"]]=[1,9]

# %%
data2
# Out:
#   Name Gender  Age Salary
# 0   p1      m    9      1
# 1   p2      f    1      0
# 2   p3      f    1      0
# 3   p4      m    9      1

# %%
data3=pd.DataFrame({"Name":["p1","p2","p3","p4"],"Gender":["m","f","f","m"],"Age":[21,2,3,4],"Salary":["25k","30k","35k","40k"]})

# %%
data3
# Out:
#   Name Gender  Age Salary
# 0   p1      m   21    25k
# 1   p2      f    2    30k
# 2   p3      f    3    35k
# 3   p4      m    4    40k

# %%
data3.loc[(data3["Gender"]=="m"),["Salary","Age"]]=[0,1]

# %%
data3
# Out:
#   Name Gender  Age Salary
# 0   p1      m    1      0
# 1   p2      f    2    30k
# 2   p3      f    3    35k
# 3   p4      m    1      0

# %%
data3.loc[:,"Name"]
# Out:
# 0    p1
# 1    p2
# 2    p3
# 3    p4
# Name: Name, dtype: object

# %%
data3.loc[:,"Name":]
# Out:
#   Name Gender  Age Salary
# 0   p1      m    1      0
# 1   p2      f    2    30k
# 2   p3      f    3    35k
# 3   p4      m    1      0

# %%
data3.loc[:,"Name":"Gender"]
# Out:
#   Name Gender
# 0   p1      m
# 1   p2      f
# 2   p3      f
# 3   p4      m

# %%
import pandas as pd
d=pd.read_csv("C:\\Users\\SSS\\Downloads\\titanic.csv")

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 1.From the DataFrame access all the rows where sex=female.

# %%
d.loc[d["Sex"]=="female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 2.Try to count how many male and female

# %%
x=print("No.of female :",len(d.loc[d["Sex"]=="female"]))
# Out:
# No.of female : 314

# %%
y=print("No.of male:",len(d.loc[d["Sex"]=="male"]))
# Out:
# No.of male: 577

# %% [markdown]
# 3.In your data convert Pclass of value 1 to class1,Pclass of value 2 to class 2,Pclass of value 3 to class 3

# %%
d.loc[:,"Pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
d.loc[(d["Pclass"]==1),["Pclass"]]=["class1"]

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1  class1
# 2              3         1       3
# 3              4         1  class1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1  class1
# 888          889         0       3
# 889          890         1  class1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d.loc[(d["Pclass"]==1),["Pclass"]]=["class1"]
d.loc[(d["Pclass"]==2),["Pclass"]]=["class2"]
d.loc[(d["Pclass"]==3),["Pclass"]]=["class3"]

# %%
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0  class3
# 1              2         1  class1
# 2              3         1  class3
# 3              4         1  class1
# 4              5         0  class3
# ..           ...       ...     ...
# 886          887         0  class2
# 887          888         1  class1
# 888          889         0  class3
# 889          890         1  class1
# 890          891         0  class3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 4.From your DataFrame access all the rows whose age is between 32 to 65

# %%
d.loc[(d["Age"]>=32) & (d["Age"]<=65)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1  class1
# 3              4         1  class1
# 4              5         0  class3
# 6              7         0  class1
# 11            12         1  class1
# ..           ...       ...     ...
# 873          874         0  class3
# 879          880         1  class1
# 881          882         0  class3
# 885          886         0  class3
# 890          891         0  class3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 5.From your DataFrame access all the rows whose name having age is between 32 to 65

# %%
d.loc[(d["Age"]>=32) & (d["Age"]<=65),"Name"]
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
#                              ...
# 873                          Vander Cruyssen, Mr. Victor
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 881                                   Markun, Mr. Johann
# 885                 Rice, Mrs. William (Margaret Norton)
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 278, dtype: object

# %% [markdown]
# 6.Check how many males are there between the age of 35 to 65

# %%
d.loc[(d["Age"]>=35) & (d["Age"]<=55)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 13            14         0       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
a=print("No. of males are there between the age of 35 to 65 :",len(d.loc[(d["Age"]>=35) & (d["Age"]<=55),["Sex"]]==["male"]))
# Out:
# No. of males are there between the age of 35 to 65 : 195

# %% [markdown]
# 7.Check how many males are there between the age of 35 to 65.

# %%
print("No. of females are there between the age of 35 to 65 :",len(d.loc[(d["Age"]>=35) & (d["Age"]<=55),["Sex"]]==["female"]))
# Out:
# No. of females are there between the age of 35 to 65 : 195

# %% [markdown]
# 8.From the DataFrame,try to find how many persons in Pclass of class3.

# %%
z=print("No.of persons in Pclass of class3 :",len(d.loc[d["Pclass"]=="class3"]))
# Out:
# No.of persons in Pclass of class3 : 491

# %% [markdown]
# 9.From the embarked column find out how many unique values are there.

# %%
import csv
with open(r"C:\\Users\\SSS\\Downloads\\titanic.csv") as f:
          input_file=f
csv_reader=csv.reader(f,delimiter=",")
uniqueIds=set()
for row in csv_reader:
       uniqueIds.add(row[0])
print(len(uniqueIds))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 4>()
#       2 with open(r"C:\\Users\\SSS\\Downloads\\titanic.csv") as f:
#       3           input_file=f
# ----> 4 csv_reader=csv.reader(f,delimiter=",")
#       5 uniqueIds=set()
#       6 for row in csv_reader:
#
# ValueError: I/O operation on closed file.

# %%
w=d.loc[:,"Embarked"]

# %%
w
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
print(len(set(w)))
# Out:
# 4
